# %% [markdown]
# <a href="https://colab.research.google.com/github/vkjadon/sklearn/blob/main/fuelConsumptionData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Automotive Monitoring
#
# Automotive data is avaiable from OBD-II codes that are standard for engine monitoring of light duty vehicles (passenger cars) starting in year 1996. Newer vehicles may include additional sensors from other electronic systems such as the brake system, tire pressure, climate control, and transmission. Data is processed with on-board computers to monitor the health of the vehicle systems and provide warning diagnostics when there is an indication of malfunction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('http://apmonitor.com/pds/uploads/Main/automotive.txt')
data.head()
# Out:
#            time  Average fuel consumption (MPG)  \
# 0  07:57:49.962                             NaN
# 1  07:57:50.227                             NaN
# 2  07:57:50.349                             NaN
# 3  07:57:50.478                             NaN
# 4  07:57:50.577                             NaN
#
#    Average fuel consumption (total) (MPG)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Average fuel consumption 10 sec (MPG)  Average speed (mph)  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN                  NaN
#
#    Calculated instant fuel consumption (MPG)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        0.0
# 4                                        NaN
#
#    Calculated instant fuel rate (gal./h)  Distance travelled (miles)  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                               0.177214                         NaN
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
#
#    Distance travelled (total) (miles)  Engine RPM (rpm)  ...  \
# 0                                 NaN               NaN  ...
# 1                                 NaN               NaN  ...
# 2                                 NaN               NaN  ...
# 3                                 NaN               NaN  ...
# 4                                 NaN             741.0  ...
#
#    Fuel used price ($)  Fuel used price (total) ($)  \
# 0                  NaN                          NaN
# 1                  NaN                          NaN
# 2                  NaN                          NaN
# 3                  NaN                          NaN
# 4                  NaN                          NaN
#
#    Instant engine power (based on fuel consumption) (hp)  \
# 0                                                NaN
# 1                                                NaN
# 2                                           1.930252
# 3                                                NaN
# 4                                                NaN
#
#    MAF air flow rate (g/sec)  Oxygen sensor 1 Wide Range Current (mA) (mA)  \
# 0                        NaN                                     -0.011719
# 1                        NaN                                           NaN
# 2                        2.0                                           NaN
# 3                        NaN                                           NaN
# 4                        NaN                                           NaN
#
#    Oxygen sensor 1 Wide Range Equivalence ratio ()  Throttle position (%)  \
# 0                                        14.702742                    NaN
# 1                                              NaN              10.588235
# 2                                              NaN                    NaN
# 3                                              NaN                    NaN
# 4                                              NaN                    NaN
#
#    Vehicle acceleration (g)  Vehicle speed (mph)  Unnamed: 22
# 0                       NaN                  NaN          NaN
# 1                       NaN                  NaN          NaN
# 2                       NaN                  NaN          NaN
# 3                       0.0                  0.0          NaN
# 4                       NaN                  NaN          NaN
#
# [5 rows x 23 columns]

# %%
# set time index
data['time'] = pd.to_datetime(data['time'])
data = data.set_index('time')
data.head()
# Out:
#                          Average fuel consumption (MPG)  \
# time
# 2022-10-31 07:57:49.962                             NaN
# 2022-10-31 07:57:50.227                             NaN
# 2022-10-31 07:57:50.349                             NaN
# 2022-10-31 07:57:50.478                             NaN
# 2022-10-31 07:57:50.577                             NaN
#
#                          Average fuel consumption (total) (MPG)  \
# time
# 2022-10-31 07:57:49.962                                     NaN
# 2022-10-31 07:57:50.227                                     NaN
# 2022-10-31 07:57:50.349                                     NaN
# 2022-10-31 07:57:50.478                                     NaN
# 2022-10-31 07:57:50.478                        NaN
# 2022-10-31 07:57:50.577                        NaN
#
#                          Oxygen sensor 1 Wide Range Current (mA) (mA)  \
# time
# 2022-10-31 07:57:49.962                                     -0.011719
# 2022-10-31 07:57:50.227                                           NaN
# 2022-10-31 07:57:50.349                                           NaN
# 2022-10-31 07:57:50.478                                           NaN
# 2022-10-31 07:57:50.577                                           NaN
#
#                          Oxygen sensor 1 Wide Range Equivalence ratio ()  \
# time
# 2022-10-31 07:57:49.962                                        14.702742
# 2022-10-31 07:57:50.227                                              NaN
# 2022-10-31 07:57:50.349                                              NaN
# 2022-10-31 07:57:50.478                                              NaN
# 2022-10-31 07:57:50.577                                              NaN
#
#                          Throttle position (%)  Vehicle acceleration (g)  \
# time
# 2022-10-31 07:57:49.962                    NaN                       NaN
# 2022-10-31 07:57:50.227              10.588235                       NaN
# 2022-10-31 07:57:50.349                    NaN                       NaN
# 2022-10-31 07:57:50.478                    NaN                       0.0
# 2022-10-31 07:57:50.577                    NaN                       NaN
#
#                          Vehicle speed (mph)  Unnamed: 22
# time
# 2022-10-31 07:57:49.962                  NaN          NaN
# 2022-10-31 07:57:50.227                  NaN          NaN
# 2022-10-31 07:57:50.349                  NaN          NaN
# 2022-10-31 07:57:50.478                  0.0          NaN
# 2022-10-31 07:57:50.577                  NaN          NaN
#
# [5 rows x 22 columns]

# %%
print(data.columns)

# %%
# print data columns
for x in data.columns:
    print(x)
# Out:
# Average fuel consumption (MPG)
# Average fuel consumption (total) (MPG)
# Average fuel consumption 10 sec (MPG)
# Average speed (mph)
# Calculated instant fuel consumption (MPG)
# Calculated instant fuel rate (gal./h)
# Distance travelled (miles)
# Distance travelled (total) (miles)
# Engine RPM (rpm)
# Fuel economizer (based on fuel system status and throttle position) ()
# Fuel used (gallon)
# Fuel used (total) (gallon)
# Fuel used price ($)
# Fuel used price (total) ($)
# Instant engine power (based on fuel consumption) (hp)
# MAF air flow rate (g/sec)
# Oxygen sensor 1 Wide Range Current (mA) (mA)
# Oxygen sensor 1 Wide Range Equivalence ratio ()
# Throttle position (%)
# Vehicle acceleration (g)
# Vehicle speed (mph)
# Unnamed: 22

# %% [markdown]
# The fillna() method replaces the NULL values with a specified value.
#
# The fillna() method returns a new DataFrame object unless the inplace parameter is set to True, in that case the fillna() method does the replacing in the original DataFrame instead.

# %%
# fill in NaNs - forward fill
data.fillna(method='ffill',inplace=True)
# fill in NaNs - backward fill
data.fillna(method='bfill',inplace=True)

# Remove last column with no column heading
del data['Unnamed: 22']

# remove columns that match keywords
for dc in data.columns:
    if ("Average" in dc) or ("(total)" in dc) or ("$" in dc) or ("(mA)" in dc):
        del data[dc]

# %%
data.head()

# %%
data.plot(subplots=True,figsize=(12,30))
plt.show()

# %%
select = ['Vehicle speed (mph)','Throttle position (%)','Engine RPM (rpm)', 'Vehicle acceleration (g)']
data[select].plot(kind='box', subplots=True, figsize=(12,3))
plt.show()

# %%
import seaborn as sns
sns.pairplot(data[select])
plt.show()

# %%
sns.heatmap(data[select].corr())
plt.show()
